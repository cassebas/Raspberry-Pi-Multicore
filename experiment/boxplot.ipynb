# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
from itertools import combinations
from itertools import combinations_with_replacement
from itertools import permutations
from itertools import product

# %%
df0 = pd.read_csv('output/20200226-array_access_random-4core.csv')
df0 = df0.loc[df0['core'] == 2]
df0.boxplot(column='cycles') 
df0.describe()
# Out:
#        cores   core        cycles   iteration  offset
# count  509.0  509.0    509.000000  509.000000   509.0
# mean     4.0    2.0  38750.469548  256.813360     0.0
# std      0.0    0.0   3930.573666  148.291406     0.0
# min      4.0    2.0  28406.000000    1.000000     0.0
# 25%      4.0    2.0  36193.000000  129.000000     0.0
# 50%      4.0    2.0  37992.000000  257.000000     0.0
# 75%      4.0    2.0  41891.000000  385.000000     0.0
# max      4.0    2.0  46869.000000  513.000000     0.0

# %%
df = pd.read_csv('output/20200122-malardalen_bsort100_1core-clearcache.csv')
df.boxplot(column='cycles') 
df.describe()
# Out:
#         cores    core        cycles    iteration  offset
# count  2036.0  2036.0  2.036000e+03  2036.000000  2036.0
# mean      1.0     0.0  2.931292e+04  1018.500000     0.0
# std       0.0     0.0  3.484270e+04   587.886894     0.0
# min       1.0     0.0  2.711700e+04     1.000000     0.0
# 25%       1.0     0.0  2.811100e+04   509.750000     0.0
# 50%       1.0     0.0  2.876500e+04  1018.500000     0.0
# 75%       1.0     0.0  2.895300e+04  1527.250000     0.0
# max       1.0     0.0  1.600513e+06  2036.000000     0.0
